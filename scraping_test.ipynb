# %% [markdown]
# ## Ideas for Scraping Websites for Data
# - Id column is ok.
# - Name: Thomas's Extension.
# - Description: Use Meta code. Thomas's Extension as a backup.
# - State column is ok.
# - City column is ok.
# - Type: Filler Value
# - Price_level: Filler Value. NEEDS EDITING LATER!!!
# - Traffic_level: Filler Value. NEEDS EDITING LATER!!!
# - Rating: Thomas's Extension.
# - Wheelchair_accessibility: Thomas's Extension.
# - Family_friendly: Thomas's Extension.
# - Pet_friendly: Filler Value. NEEDS EDITING LATER!!!
# - Website: Thomas's Extension.
# - Lat: Use Geopy Code.
# - Long: Use Geopy Code.
# - Image column: Thomas's Extension.

# %%
import pandas as pd
from bs4 import BeautifulSoup
import geocoder
import glob
import regex as re
import numpy as np
import requests

# %%
all_data = pd.DataFrame()
for file in glob.glob("rawCSV/*"):
    city_data = pd.read_csv(file)
    all_data = all_data.append(city_data)
# Out:
# /var/folders/m1/008bc_qj10xcw14crt8tq1580000gn/T/ipykernel_3461/1365880037.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   all_data = all_data.append(city_data)
# /var/folders/m1/008bc_qj10xcw14crt8tq1580000gn/T/ipykernel_3461/1365880037.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   all_data = all_data.append(city_data)
# /var/folders/m1/008bc_qj10xcw14crt8tq1580000gn/T/ipykernel_3461/1365880037.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   all_data = all_data.append(city_data)
# /var/folders/m1/008bc_qj10xcw14crt8tq1580000gn/T/ipykernel_3461/1365880037.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
# ...

# %%
for id, element in enumerate(all_data['web-scraper-order']):
    element = element[-3:]
    all_data['web-scraper-order'][id] = element
# Out:
# /var/folders/m1/008bc_qj10xcw14crt8tq1580000gn/T/ipykernel_3461/2456694522.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   all_data['web-scraper-order'][id] = element
# /var/folders/m1/008bc_qj10xcw14crt8tq1580000gn/T/ipykernel_3461/2456694522.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   all_data['web-scraper-order'][id] = element
# /var/folders/m1/008bc_qj10xcw14crt8tq1580000gn/T/ipykernel_3461/2456694522.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# ...

# %%
def combiner(df):
    odds = list(range(1, len(df) + 1, 2))
    evens = list(range(2, len(df) + 1, 2))
    combined_all_data = pd.DataFrame()
    for number in range(0,len(evens)):
        odd_number = odds[number]
        even_number = evens[number]
        combined_datapoint = df.iloc[odd_number-1].combine_first(df.iloc[even_number-1])
        combined_all_data = combined_all_data.append(combined_datapoint)
    return combined_all_data


all_data = all_data.groupby('web-scraper-start-url')[['name', 'rating', 'website', 'location', 'wheelchair', 'family', 'image_link-src', 'description']].first()
combined_all_data = combiner(all_data)
combined_all_data
# Out:
# /var/folders/m1/008bc_qj10xcw14crt8tq1580000gn/T/ipykernel_3461/491469402.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   combined_all_data = combined_all_data.append(combined_datapoint)
# /var/folders/m1/008bc_qj10xcw14crt8tq1580000gn/T/ipykernel_3461/491469402.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   combined_all_data = combined_all_data.append(combined_datapoint)
# /var/folders/m1/008bc_qj10xcw14crt8tq1580000gn/T/ipykernel_3461/491469402.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   combined_all_data = combined_all_data.append(combined_datapoint)
# ...

# %%
description_list = []
for url in combined_all_data['website']:
    if bool(url):
        try:
            page = requests.get('http://' + url)
            soup = BeautifulSoup(page.content, "html.parser")
            metas = soup.find_all('meta')
            description = [ meta.attrs['content'] for meta in metas if 'name' in meta.attrs and meta.attrs['name'] == 'description' ]
            # print(''.join(description))
            description_list.append(''.join(description))
        except:
            description_list.append(None)
    else:
        description_list.append(None)
description_list
# Out:
# WELCOME PAGE 2 DOORS DOWN
#
#
# Agecroft Hall & Gardens is a majestic Tudor mansion built in the late 15th Century in England and brought to Richmond, Virginia piece by piece. The home is located on 23 beautifully landscaped acres overlooking the James River in the neighborhood of Windsor Farms, less than 1 mile from downtown Richmond.
#
#
# Online ordering menu for Asian Garden. Welcome to Asian Garden where we serve Japanese and Chinese cuisine! You can find Miso Soup, Yaki Udon, General Tso's Shrimp, and more on our menu! We're located east of I-81 on Foxcroft Ave. Order online for carryout or delivery!
# Athenaeum | NVFAA, welcome, historic building, regional art gallery, special event space for rent, greek revival architecture, The Athenaeum, 201 Prince Street, Alexandria, VA 22314
# ...

# %%
combined_all_data['meta_descriptions'] = description_list
combined_all_data
# Out:
#                                                                                               name  \
# https://www.google.com/maps/place/2+Doors+Down/...                                    2 Doors Down
# https://www.google.com/maps/place/Action+City/@...                                     Action City
# https://www.google.com/maps/place/Adams+Museum/...                                    Adams Museum
# https://www.google.com/maps/place/Agecroft+Hall...                         Agecroft Hall & Gardens
# https://www.google.com/maps/place/Air+Power+Par...                                  Air Power Park
# ...                                                                                            ...
# https://www.google.com/maps/place/Wonderfeet+Ki...                         Wonderfeet Kid's Museum
# https://www.google.com/maps/place/World's+Fair+...                               World's Fair Park
# ...

# %%
locator = GoogleV3(api_key="AIzaSyDUWchqTkzvxteGNb_tDPCR3jvL1k5J_g4", user_agent="scraping_test.ipynb")
location = locator.geocode("2054 East Rocklin Drive, Sandy UT")
print("Latitude = {}, Longitude = {}".format(location.latitude, location.longitude))

# %%
'''
def find_lat(maps_url):
    lat = re.findall('(?<=https:\/\/www.google.com\/maps\/place\/[^\/]*\/@)([^,]*)',maps_url)
    return lat
def find_lon(maps_url):
    lon = re.findall('(?<=https:\/\/www.google.com\/maps\/place\/[^\/]*\/@?[^,]*,)([^,]*)',maps_url)
    return lon

find_lat('https://www.google.com/maps/place/Bay+Beach+Amusement+Park/@44.5311737,-88.6586618,')
find_lon('https://www.google.com/maps/place/Bay+Beach+Amusement+Park/@44.5311737,-88.6586618,')
'''
# Out:
# "\ndef find_lat(maps_url):\n    lat = re.findall('(?<=https:\\/\\/www.google.com\\/maps\\/place\\/[^\\/]*\\/@)([^,]*)',maps_url)\n    return lat\ndef find_lon(maps_url):\n    lon = re.findall('(?<=https:\\/\\/www.google.com\\/maps\\/place\\/[^\\/]*\\/@?[^,]*,)([^,]*)',maps_url)\n    return lon\n\nfind_lat('https://www.google.com/maps/place/Bay+Beach+Amusement+Park/@44.5311737,-88.6586618,')\nfind_lon('https://www.google.com/maps/place/Bay+Beach+Amusement+Park/@44.5311737,-88.6586618,')\n"

# %%
'''
gb['latitude'] = gb['web-scraper-start-url'].apply(find_lat)
gb['longtitude'] = gb['web-scraper-start-url'].apply(find_lon)
gb
'''
# Out:
# "\ngb['latitude'] = gb['web-scraper-start-url'].apply(find_lat)\ngb['longtitude'] = gb['web-scraper-start-url'].apply(find_lon)\ngb\n"

# %%
#website_soup = BeautifulSoup(open("rocketcenterwebsite.html"))

print(website_soup.prettify())

# %%
# Get title
website_soup.title
# Out:
# <title>U.S. Space &amp; Rocket Center | Home of Space Camp</title>

# %%
metas = website_soup.find_all('meta')

print([ meta.attrs['content'] for meta in metas if 'name' in meta.attrs and meta.attrs['name'] == 'description' ])
# Out:
# ['The Official Visitor Center for NASA’s Marshall Space Flight Center, the U.S. Space & Rocket Center is a Smithsonian Affiliate museum with one of the largest collections of rockets and space memorabilia on display anywhere in the world and is the home of Space Camp programs and the INTUITIVE Planetarium. Located in Huntsville, Alabama.']

# %%
website_two_soup = BeautifulSoup(open("Incomplete.html"))
website_two_soup.title
# Out:
# <title>Homepage - Huntsville Museum of Art - bringing people &amp; art together</title>

# %%
metas = website_soup.find_all('meta')

print([ meta.attrs['content'] for meta in metas if 'name' in meta.attrs and meta.attrs['name'] == 'description' ])
# Out:
# ['The Official Visitor Center for NASA’s Marshall Space Flight Center, the U.S. Space & Rocket Center is a Smithsonian Affiliate museum with one of the largest collections of rockets and space memorabilia on display anywhere in the world and is the home of Space Camp programs and the INTUITIVE Planetarium. Located in Huntsville, Alabama.']

# %%
website_three_soup = BeautifulSoup(open("poboyfactory.html"))
website_three_soup.title
# Out:
# <title>
#     Cajun Restaurant | Huntsville, AL | The Po Boy Factory
#   </title>

# %%
metas = website_three_soup.find_all('meta')

print([ meta.attrs['content'] for meta in metas if 'name' in meta.attrs and meta.attrs['name'] == 'description' ])
# Out:
# ['The Po Boy Factory in Huntsville, AL brings New Orleans style cuisine Alabama. Bring your family to the big yellow house on Andrew Jackson Way.']

# %%
g = geocoder.GoogleV3("AIzaSyDUWchqTkzvxteGNb_tDPCR3jvL1k5J_g4")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Input In [100], in <cell line: 1>()
# ----> 1 g = geocoder.GoogleV3("AIzaSyDUWchqTkzvxteGNb_tDPCR3jvL1k5J_g4")
#
# AttributeError: module 'geocoder' has no attribute 'GoogleV3'

# %%
# This gets location
from geopy import GoogleV3

locator = GoogleV3(api_key="AIzaSyDUWchqTkzvxteGNb_tDPCR3jvL1k5J_g4", user_agent="scraping_test.ipynb")
location = locator.geocode("2054 E. Rocklin Drive, Sandy UT")
# Out:
# ---------------------------------------------------------------------------
# timeout                                   Traceback (most recent call last)
# File ~/opt/anaconda3/lib/python3.9/site-packages/urllib3/connection.py:174, in HTTPConnection._new_conn(self)
#     173 try:
# --> 174     conn = connection.create_connection(
#     175         (self._dns_host, self.port), self.timeout, **extra_kw
#     176     )
#     178 except SocketTimeout:
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/urllib3/util/connection.py:95, in create_connection(address, timeout, source_address, socket_options)
#      94 if err is not None:
# ---> 95     raise err
#      97 raise socket.error("getaddrinfo returns an empty list")
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/urllib3/util/connection.py:85, in create_connection(address, timeout, source_address, socket_options)
#      84     sock.bind(source_address)
# ---> 85 sock.connect(sa)
#      86 return sock
#
# timeout: timed out
#
# ...

# %%
print("Latitude = {}, Longitude = {}".format(location.latitude, location.longitude))
# Out:
# Latitude = 40.5741141, Longitude = -111.8327078

# %%
locator = GoogleV3(api_key="AIzaSyDUWchqTkzvxteGNb_tDPCR3jvL1k5J_g4", user_agent="scraping_test.ipynb")
location = locator.geocode("2054 East Rocklin Drive, Sandy UT")
print("Latitude = {}, Longitude = {}".format(location.latitude, location.longitude))
# Out:
# Latitude = 40.5741141, Longitude = -111.8327078

# %%
api_key = 'AIzaSyDUWchqTkzvxteGNb_tDPCR3jvL1k5J_g4'

# %%
# 
website_soup.title
# Out:
# <title>U.S. Space &amp; Rocket Center | Home of Space Camp</title>
